# %% [markdown]
# # Langchain Version V1

# %%
import os
from dotenv import load_dotenv
load_dotenv()

import langchain
langchain.__version__
# Out:
# '1.3.17'

# %%
os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")

# %% [markdown]
# # Create Agent

# %%
from langchain.agents import create_agent


def get_weather(city:str)-> str:
    """Get the weather for a city"""
    return f"The weather in {city} is sunny."
    
agent=create_agent(
    model="gpt-5",
    tools=[],
    system_prompt="You are a helpful assistent"
)

agent
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[3], line 8
#       5     """Get the weather for a city"""
#       6     return f"The weather in {city} is sunny."
# ----> 8 agent=create_agent(
#       9     model="gpt-5",
#      10     tools=[],
#      11     system_prompt="You are a helpful assistent"
#      12 )
#      14 agent
#
# File e:\KrishLangChainPractice\.venv\lib\site-packages\langchain\agents\factory.py:996, in create_agent(model, tools, system_prompt, middleware, response_format, state_schema, context_schema, checkpointer, store, interrupt_before, interrupt_after, debug, name, cache, transformers)
#     994 # init chat model
#     995 if isinstance(model, str):
# --> 996     model = init_chat_model(model)
#     998 # Convert system_prompt to SystemMessage if needed
#     999 system_message: SystemMessage | None = None
#
# File e:\KrishLangChainPractice\.venv\lib\site-packages\langchain\chat_models\base.py:516, in init_chat_model(model, model_provider, configurable_fields, config_prefix, **kwargs)
#     508     warnings.warn(
#     509         f"{config_prefix=} has been set but no fields are configurable. Set "
#     510         f"`configurable_fields=(...)` to specify the model params that are "
#     511         f"configurable.",
#     512         stacklevel=2,
#     513     )
#     515 if not configurable_fields:
# --> 516     return _init_chat_model_helper(
#     517         cast("str", model),
#     518         model_provider=model_provider,
#     519         **kwargs,
#     520     )
#     521 if model:
#     522     kwargs["model"] = model
#
# File e:\KrishLangChainPractice\.venv\lib\site-packages\langchain\chat_models\base.py:540, in _init_chat_model_helper(model, model_provider, **kwargs)
#     538 model, model_provider = _parse_model(model, model_provider)
#     539 creator_func = _get_chat_model_creator(model_provider)
# --> 540 return creator_func(model=model, **kwargs)
#
# File e:\KrishLangChainPractice\.venv\lib\site-packages\langchain\chat_models\base.py:53, in _call(cls, **kwargs)
#      51 def _call(cls: type[BaseChatModel], **kwargs: Any) -> BaseChatModel:
#      52     # TODO: replace with operator.call when lower bounding to Python 3.11
# ---> 53     return cls(**kwargs)
#
# File e:\KrishLangChainPractice\.venv\lib\site-packages\langchain_core\load\serializable.py:136, in Serializable.__init__(self, *args, **kwargs)
#     134 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     135     """"""  # noqa: D419  # Intentional blank docstring
# --> 136     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File e:\KrishLangChainPractice\.venv\lib\site-packages\langchain_openai\chat_models\base.py:1441, in BaseChatOpenAI.validate_environment(self)
#    1427         self.http_async_client = _build_proxied_async_httpx_client(
#    1428             proxy=self.openai_proxy,
#    1429             verify=global_ssl_context,
#    1430             socket_options=resolved_socket_options,
#    1431         )
#    1432     async_specific = {
#    1433         "http_client": self.http_async_client
#    1434         or _get_default_async_httpx_client(
#    (...)
#    1439         "api_key": async_api_key_value,
#    1440     }
# -> 1441     self.root_async_client = openai.AsyncOpenAI(
#    1442         **client_params,
#    1443         **async_specific,  # type: ignore[arg-type]
#    1444     )
#    1445     self.async_client = self.root_async_client.chat.completions
#    1446 return self
#
# File e:\KrishLangChainPractice\.venv\lib\site-packages\openai\_client.py:947, in AsyncOpenAI.__init__(self, api_key, admin_api_key, workload_identity, organization, project, webhook_secret, provider, base_url, data_residency, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation, _enforce_credentials)
#     937 self.admin_api_key = admin_api_key if provider_runtime is None else None
#     939 if (
#     940     provider_runtime is None
#     941     and _enforce_credentials
#    (...)
#     945     and self.admin_api_key is None
#     946 ):
# --> 947     raise OpenAIError(
#     948         "Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable."
#     949     )
#     951 if organization is None and provider_runtime is None:
#     952     organization = os.environ.get("OPENAI_ORG_ID")
#
# OpenAIError: Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable.

# %%
response=agent.invoke({"messages":[{"role":"user", "content":"What is the weather in New York"}]})

# %%
response["messages"][-1].content

# %%
response=agent.invoke({"messages":"What is the weather in New York"})
