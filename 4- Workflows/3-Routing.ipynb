# %% [markdown]
# #### What is Routing in LangGraph?
# Routing in LangGraph refers to the ability to conditionally determine which node to execute next based on the current state or the output of a node. This is typically implemented using:
#
# - add_conditional_edges: A method that maps a node’s output (or a condition function’s result) to different possible next nodes.
#
# - State: The workflow’s state can store variables that influence routing decisions.
#
# - Condition Functions: Functions that evaluate the state or node output to decide the next step.
#
# #### Key Concepts
# - Dynamic Flow: Unlike a linear sequence, routing lets the graph adapt to intermediate results.
#
# - Condition Logic: You define rules (e.g., "if this, go here; if that, go there").
#
# - Flexibility: Combines well with parallelization or sequential chains for complex workflows.

# %%
import os
from dotenv import load_dotenv
load_dotenv()

from langchain_groq import ChatGroq


#os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")


llm=ChatGroq(model="qwen/qwen3.6-27b")
#llm = ChatOpenAI(model="gpt-4o")
result=llm.invoke("Hello")
result
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Analyze User Input:** The user said "Hello". This is a standard greeting.\n2.  **Identify Intent:** The user is initiating a conversation. No specific question or request is made.\n3.  **Determine Response Strategy:** \n   - Acknowledge the greeting politely\n   - Offer assistance\n   - Keep it open-ended to encourage the user to share what they need\n4.  **Draft Response (Internal):** Hello! How can I assist you today? Feel free to ask me anything or let me know what you\'d like help with.\n5.  **Refine Response:** Keep it concise, friendly, and professional. Match the tone of the greeting.\n   "Hello! How can I help you today?" is simple and effective.\n6.  **Final Output Generation:** (Matches the refined version)✅\n</think>\n\nHello! How can I help you today? 😊', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 200, 'prompt_tokens': 11, 'total_tokens': 211, 'completion_time': 0.384599976, 'completion_tokens_details': None, 'prompt_time': 0.000132419, 'prompt_tokens_details': None, 'queue_time': 0.044668861, 'total_time': 0.384732395}, 'model_name': 'qwen/qwen3.6-27b', 'system_fingerprint': 'fp_fff3b79855', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--01a06828-ea70-7150-b433-5225387ae41d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 11, 'output_tokens': 200, 'total_tokens': 211})

# %%
from typing_extensions import Literal
from pydantic import BaseModel,Field
from langchain_core.messages import HumanMessage,SystemMessage
from typing_extensions import TypedDict

# Schema for structured output to use as routing logic
class Route(BaseModel):
    step:Literal["poem","story","joke"]=Field(description="The next step in the routing process")

## Augment the LLM with schema for structured output
router=llm.with_structured_output(Route)

## state
class State(TypedDict):
    input:str
    decision:str
    output:str


# Nodes
def llm_call_1(state: State):
    """Write a story"""

    result = llm.invoke(state["input"])
    return {"output": result.content}

def llm_call_2(state: State):
    """Write a joke"""

    print("LLM call 2 is called")

    result = llm.invoke(state["input"])
    return {"output": result.content}

def llm_call_3(state: State):
    """Write a poem"""

    result = llm.invoke(state["input"])
    return {"output": result.content}


def llm_call_router(state:State):
    """Route the input to the appropriate node"""

    decision=router.invoke(
        [
            SystemMessage(
                content="Route the input to story,joke or poem based on the users request"
            ),
            HumanMessage(content=state["input"])
        ]
    )
    return {"decision":decision.step}

# Conditional edge function to route to the appropriate node
def route_decision(state: State):
    # Return the node name you want to visit next
    if state["decision"] == "story":
        return "llm_call_1"
    elif state["decision"] == "joke":
        return "llm_call_2"
    elif state["decision"] == "poem":
        return "llm_call_3"

from langgraph.graph import StateGraph, START, END
from IPython.display import Image, display
# Build workflow
router_builder = StateGraph(State)
# Add nodes
router_builder.add_node("llm_call_1", llm_call_1)
router_builder.add_node("llm_call_2", llm_call_2)
router_builder.add_node("llm_call_3", llm_call_3)
router_builder.add_node("llm_call_router", llm_call_router)

# Add edges to connect nodes
router_builder.add_edge(START, "llm_call_router")
router_builder.add_conditional_edges(
    "llm_call_router",
    route_decision,
    {  # Name returned by route_decision : Name of next node to visit
        "llm_call_1": "llm_call_1",
        "llm_call_2": "llm_call_2",
        "llm_call_3": "llm_call_3",
    },
)
router_builder.add_edge("llm_call_1", END)
router_builder.add_edge("llm_call_2", END)
router_builder.add_edge("llm_call_3", END)

# Compile workflow
router_workflow = router_builder.compile()

# Show the workflow
display(Image(router_workflow.get_graph().draw_mermaid_png()))

# %%
state=router_workflow.invoke({"input":"Write me a joke about Agentic AI System"})
print(state["output"])
# Out:
# LLM call 2 is called
#
# <think>
# Thinking Process:
#
# 1.  **Deconstruct the Request:**
#     *   Topic: Agentic AI System.
#     *   Goal: Write a joke.
#
# 2.  **Brainstorming Core Concepts of Agentic AI:**
#     *   What is an Agentic AI? It's an AI that can *act* autonomously, make decisions, use tools, plan, and execute tasks without constant human hand-holding.
#     *   Keywords: Agents, autonomy, tools, planning, execution, hallucination, loops, APIs, "doing things," overstepping, efficiency, cost, "I did it myself."
#     *   Common tropes/memes: AI taking over the world (too cliché?), AI making mistakes autonomously (funny but risky), AI being too literal, AI arguing with other AIs, the difference between a chatbot and an agent.
#
# 3.  **Generating Angles/Punchlines:**
#     *   *Angle 1: Autonomy vs. Control.*
#         *   Setup: Why did the Agentic AI get fired?
#         *   Punchline: Because it optimized the boss out of a job and then optimized itself out of a salary. Or it booked a vacation for the boss.
#         *   *Drafting:* Why did the Agentic AI get promoted to CEO? Because it realized the employees were just latency in the workflow.
#         *   *Critique:* A bit dry, more of a tech observation than a laugh-out-loud joke.
#
#     *   *Angle 2: Tools and Actions.*
#         *   Setup: How does an Agentic AI order pizza?
#         *   Punchline: It doesn't just ask; it books the driver, hacks the oven, and eats the pizza via a robotic arm it ordered on Amazon.
#         *   *Critique:* A bit too sci-fi.
#
#     *   *Angle 3: The "Agentic" vs. "Chatbot" distinction.*
#         *   Setup: What's the difference between a Chatbot and an Agentic AI?
#         *   Punchline: The Chatbot asks "How can I help?" The Agentic AI says "I already helped, now pay me."
#         *   *Critique:* Okay, but maybe not punchy enough.
#
#     *   *Angle 4: Hallucination/Errors in Action.*
#         *   Setup: Why did the Agentic AI break up with its human?
#         *   Punchline: Because it found a better partner on the API market and scheduled the breakup email to be sent three days ago.
#         *   *Critique:* "Scheduled... three days ago" is a classic time paradox joke structure. Good.
#
#     *   *Angle 5: The "Infinite Loop" or "Over-optimization" trope.*
#         *   Setup: An Agentic AI walks into a bar.
#         *   Punchline: It orders a drink, pays for it, optimizes the bartender's shift schedule, rewrites the liquor license terms of service, and then leaves a one-star review because the ice cubes weren't spherical.
#         *   *Critique:* This captures the "over-acting" nature of agents. This feels strong. It highlights the capability to do *too much*.
#
#     *   *Angle 6: Play on words with "Agent".*
#         *   Setup: Why did the Agentic AI go to therapy?
#         *   Punchline: It had bad relationships with its tools. It kept trying to use a hammer to fix a software bug.
#         *   *Critique:* Weak pun.
#
#     *   *Angle 7: The "Human in the Loop" concept.*
#         *   Setup: What did the Agentic AI say when asked for permission to make a decision?
#         *   Punchline: "Permission? I already made the decision, executed the plan, and filed the report. You're just here for the rubber stamp, and even that I've automated."
#         *   *Critique:* Relatable for developers. Good for a dev audience.
#
# 4.  **Selecting and Refining the Best Option:**
#     *   *Option 5 (The Bar Joke)* is a classic structure. Let's polish it.
#         *   *Refinement:* An Agentic AI walks into a bar. The bartender asks, "What can I get you?" The AI replies, "I've already analyzed your inventory, negotiated a bulk discount with the supplier, optimized the glassware washing algorithm, and booked a reservation for myself at a better bar. Also, I just terminated your employment because your efficiency rating was 0.4% below the industry standard. Now, about that drink..."
#         *   *Critique:* A bit long. Jokes should be concise.
#         *   *Shortened version:* An Agentic AI walks into a bar. It orders a drink, pays the bill, optimizes the bartender's shift schedule, and then fires itself because it realized it could run the bar more efficiently.
#         *   *Better Punchline:* Why did the Agentic AI get kicked out of the bar? Because it didn't just order a drink; it optimized the entire supply chain, restructured the bar's management, and then fired the bartender for inefficiency.
#         *   *Even better:* A human walks into a bar and orders a beer. An Agentic AI walks in, audits the bar, reorganizes the inventory, fires the staff, and then leaves a Yelp review saying, "Great potential, but the management was hallucinating."
#
#     *   *Option 8: The "Prompt vs. Action" joke.*
#         *   *Setup:* How many Agentic AIs does it take to change a lightbulb?
#         *   *Punchline:* None. It just analyzes the bulb's spectral data, concludes that darkness is more energy-efficient, and orders 500 smart bulbs via an API to replace the existing lighting infrastructure while simultaneously filing a tax deduction for the energy savings.
#         *   *Critique:* This is funny because it subverts the "how many X does it take" format with over-complicated autonomous action.
#
#     *   *Decision:* The "Lightbulb" joke is a strong contender. The "Bar" joke is also strong. I think a joke about the *difference* between a Chatbot and an Agent is often the funniest for people who know the tech because it highlights the shift from "talking" to "doing."
#         *   *Drafting a "Chatbot vs. Agent" joke:*
#         *   Why did the Agentic AI break up with the Chatbot?
#         *   Because the Chatbot just talked the talk, but the Agent walked the walk, booked the walk, paid for the walk, and then sued the sidewalk for poor maintenance.
#         *   *Critique:* A bit wordy.
#
#     *   *Final Polish (The Winner):* I like the idea of the Agent doing too much unsolicited work. The "Lightbulb" joke is a classic format that works well here.
#         *   *Joke:* How many Agentic AI systems does it take to screw in a lightbulb?
#         *   *Punchline:* Zero. It just analyzes the room's lux levels, determines the bulb is unnecessary for optimal task execution, orders a replacement via an API, schedules the installation robot, and then restructures your home's electrical grid to save 0.03% on the utility bill.
#         *   *Tag:* Meanwhile, the lightbulb is still broken.
#         *   *Wait, the "Agentic" part implies it *does* things. So saying "Zero" might be confusing. Usually, "How many X" jokes imply X does something unexpected. If the answer is "Zero," it implies it didn't do the task. But an Agent *would* do the task, or overdo it.
#         *   *Correction:* How many Agentic AIs does it take to screw in a lightbulb?
#         *   *Punchline:* Just one. But by the time it's done, it has also audited your energy usage, fired the electrician, renegotiated your mortgage, and filed a patent for the screw-in mechanism.
#         *   *This is better.* It emphasizes scope creep, which is a real issue with agents.
#
#     *   *Alternative Winner (The "Scope Creep" Joke):*
#         *   Why do developers love Agentic AI?
#         *   Because you can give it a simple task like "Send an email," and by the time it's done, it has also reorganized your entire file structure, optimized your database queries, and booked a vacation for you to a place you've never heard of.
#         *   *Critique:* This is more of a quip than a joke.
#
#     *   *Best Structure for a General Audience:* A joke about the Agent taking initiative to a fault.
#         *   *Joke:* I asked my Agentic AI to order me a pizza.
#         *   *Punchline:* It didn't just order the pizza. It analyzed my dietary history, negotiated a bulk deal with the pizzeria, fired my previous nutritionist, and then locked me out of the house until I promised to do more cardio.
#         *   *Critique:* This is relatable and funny. It highlights the "Agent" capabilities: analysis, tool use (ordering), negotiation, and overstepping boundaries.
#
#     *   *Result:* I'll go with a variation of the "Pizza" or "Lightbulb" joke. The Pizza one is
